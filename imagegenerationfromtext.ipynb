# %% [markdown]
# <a href="https://colab.research.google.com/github/Narmatha2007/PRODIGY_GA_02/blob/main/imagegenerationfromtext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers accelerate torch torchvision --quiet
from diffusers import StableDiffusionPipeline
import torch

from huggingface_hub import login
login()

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "runwayml/stable-diffusion-v1-5"

pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    torch_dtype=torch.float16
)

pipe = pipe.to("cuda")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
prompt = "a 3D image of a girl doll, well detailed"
image = pipe(prompt).images[0]
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
